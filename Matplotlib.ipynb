# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
from matplotlib import pyplot as plt

# %%
x=[5,2,9,4,7]
y=[10,5,8,4,2]

# %%
# simple plot
plt.plot(x,y)
plt.xlabel("X axis")
plt.show()

# %%
# bar plot
plt.bar(x,y)
plt.show()

# %%
# scatter plot
plt.scatter(x,y);

# %%
# simple plot
import math
import numpy as np
x=np.arange(0,math.pi*2,0.05)
y=np.sin(x)
plt.plot(x,y)
plt.xlabel("Angle")
plt.ylabel("Sine")
plt.title("Sine Wave")
plt.show()

# %%
from pylab import *
x=linspace(-3,3,30)
plot(x,sin(x))
plot(x,cos(x),'r.')
plot(x,-sin(x),'g--')
show()

# %%
# Object- oriented interface
import numpy as np
import math
x=np.arange(0,math.pi*2,0.05)
y=np.sin(x)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1]) # adds axes to figure axes(left,bottom,width,height) **[ between 0 - 1 ]
ax.plot(x,y)
ax.set_title("Sine Wave")
ax.set_xlabel("Angle")
ax.set_ylabel("Sine")
# ax.legend(handles,labels,loc)
plt.show()

# %%
y=[1,4,9,16,25,36,49,64]
x1=[1,16,30,42,55,68,77,88]
x2=[1,6,12,18,28,40,52,65]
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
l1=ax.plot(x1,y,'ys-')   # solid line with yellow color and square marker
l2=ax.plot(x2,y,'go--')  # dash line with green color and circle marker
ax.legend(labels=('tv','smartphone'),loc='lower right') # legendplaced at lower right corner
ax.set_ylabel('sales')
plt.show()

# %%
# multiplot 
# plt.subplot(subplot(nrows,ncols,index))

# %%
#plot a line implicitly creating a subplot(111) 
plt.plot([1,2,3])
#now create a subplot which represnts the top plot of a grid with 2 rows and 1 column.
# since this subplot will overlap the first, the plot (and its axes)previously created, will be removed  
plt.subplot(211)
plt.plot(range(12))
plt.subplot(212,facecolor='y')# created 2nd subplot with yellow background
plt.plot(range(12));

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot([1,2,3])
ax2=fig.add_subplot(221,facecolor='y')  # 221: 2nd row, 2nd col and 1st index
ax2.plot([1,2,3])

# %%
x=np.arange(0,math.pi*2,0.05)
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
# main axes
axes2=fig.add_axes([0.55,0.55,0.3,0.3])
# insert axes
y=np.sin(x)
axes1.plot(x,y,'b')
axes2.plot(x,np.cos(x),'r')
axes1.set_title("Sine")
axes2.set_title("Cosine")
plt.show()

# %%
# subplot2grid() function :
a1=plt.subplot2grid((3,3),(0,0),colspan=2)
a2=plt.subplot2grid((3,3),(0,2),rowspan=3)
a3=plt.subplot2grid((3,3),(1,0),rowspan=2,colspan=2)

x=np.arange(1,10)
a2.plot(x,x*x)
a2.set_title("Square")
a1.plot(x,np.exp(x))
a1.set_title("Exp")
a3.plot(x,np.log(x))
a3.set_title("Log(x)")
plt.tight_layout()
plt.show()

# %%
# grid On or off
fig,axes=plt.subplots(1,3,figsize=(12,4))
x =np.arange(1,11)
axes[0].plot(x,x**3,'g',lw=2)
axes[0].grid(True)
axes[0].set_title("default grid")
axes[1].plot(x,np.exp(x),'r')
axes[1].grid(color='b',ls='-',lw=0.25)
axes[1].set_title("custom grid")
axes[2].plot(x,x)
axes[2].set_title("no grid")
fig.tight_layout()
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(10,4))
x=np.arange(1,5)
axes[0].plot(x,np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal Sacle")
axes[1].plot(x,np.exp(x))
axes[1].plot(x,x**2)
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)")
axes[0].set_xlabel("X axis")
axes[0].set_ylabel("Y axis")
axes[0].xaxis.labelpad=10
axes[1].set_xlabel(" x axis")
axes[1].set_ylabel("y axis")
plt.show(0)

# %%
# formatting axes
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.spines['bottom'].set_color("blue")
ax.spines['left'].set_color('red')
ax.spines['left'].set_linewidth(2)
ax.spines["right"].set_color(None)
ax.spines['top'].set_color(None)
ax.plot([1,2,3,4,5])
plt.show()
